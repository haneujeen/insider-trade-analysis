# %%
"""
Table Definitions
The fields in the tables below provide the following information: field name, description, data format, maximum field size, an indication of whether or not the field may be NULL (yes or no), and key. 

The Key field indicates whether the field is part of a unique index on the data.  There are two possible values for this field:

·         "*"   Indicates the field is part of the unique key for the row.  
·         Empty (nothing in field) means the field is not part of the unique compound key.
"""
# Out:
# '\nTable Definitions\nThe fields in the tables below provide the following information: field name, description, data format, maximum field size, an indication of whether or not the field may be NULL (yes or no), and key. \n\nThe Key field indicates whether the field is part of a unique index on the data.  There are two possible values for this field:\n\n·         "*"   Indicates the field is part of the unique key for the row.  \n·         Empty (nothing in field) means the field is not part of the unique compound key.\n'

# %%
"""
SUBMISSION

Field Name | Description | Data Type | Nullable |Key

ACCESSION_NUMBER
Unique identifier assigned by the SEC to each EDGAR submission.
VARCHAR2 (25)
No
*

FILING_DATE
Filing date with the Commission; sourced from EDGAR in (DD-MON-YYYY) format.
DATE
No
 
PERIOD_OF_REPORT
Date of event requiring statement in (DD-MON-YYYY) format.
DATE
No
 
DATE_OF_ORIG_SUB
If the original form is amended, this field corresponds to the date of original filing in (DD-MON-YYYY) format.
DATE
Yes
 
NO_SECURITIES_OWNED
Derived value on Form 3 based on the number of entries in <nonDerativeTable> and <DerativeTable> sections of document.  True (1) for no securities are beneficially owned; otherwise false (0).
VARCHAR (1)
Yes
 
NOT_SUBJECT_SEC16
In a Form 4 or Form 5, true (1) for a reporting person not subject to Section 16 and no transaction or holdings reporting in <nonDerativeTable> and <DerativeTable> sections of document.
VARCHAR (1)
Yes
 
FORM3_HOLDING_REPORTED
EDGAR derived value on Form 5 based on the number of <nonDerivativeHolding> and <derivativeHolding> elements with a <transactionFormType> value of “3.” If at least one “3” holding is being reported, EDGAR will set this element to true (1). Otherwise, it will be set to false (0).
VARCHAR (1)
Yes
 
FORM4_TRANS_REPORTED
EDGAR derived value on Form 5 based on the number of <nonDerivativeTransaction> and <derivativeTransaction> elements with a <transactionFormType> value of “4.” If at least one “4” transaction is being reported, EDGAR will set this element to true (1). Otherwise, it will be set to false (0).
VARCHAR(1)
Yes
 
DOCUMENT_TYPE
Submission type is either an initial filing Form 3, 4, 5 or an amendment of either 3/A, 4/A or 5/A.
VARCHAR (20)
No
 
ISSUERCIK
Central Index Key of issuer.
VARCHAR2 (10)
No
 
ISSUERNAME
Name of the issuer.
VARCHAR2 (150)
No
 
ISSUERTRADINGSYMBOL
Issuer trading symbol.
VARCHAR2 (10)
No
 
REMARKS
Remarks from reporting owner.
VARCHAR2 (2000)
Yes
"""
# Out:
# '\nSUBMISSION\n\nField Name | Description | Data Type | Nullable |Key\n\nACCESSION_NUMBER\nUnique identifier assigned by the SEC to each EDGAR submission.\nVARCHAR2 (25)\nNo\n*\n\nFILING_DATE\nFiling date with the Commission; sourced from EDGAR in (DD-MON-YYYY) format.\nDATE\nNo\n \nPERIOD_OF_REPORT\nDate of event requiring statement in (DD-MON-YYYY) format.\nDATE\nNo\n \nDATE_OF_ORIG_SUB\nIf the original form is amended, this field corresponds to the date of original filing in (DD-MON-YYYY) format.\nDATE\nYes\n \nNO_SECURITIES_OWNED\nDerived value on Form 3 based on the number of entries in <nonDerativeTable> and <DerativeTable> sections of document.  True (1) for no securities are beneficially owned; otherwise false (0).\nVARCHAR (1)\nYes\n \nNOT_SUBJECT_SEC16\nIn a Form 4 or Form 5, true (1) for a reporting person not subject to Section 16 and no transaction or holdings reporting in <nonDerativeTable> and <DerativeTable> sections of document.\nVARCHAR (1)\nYes\n \nFORM3_HOLDING_REPORTED\nEDGAR derived value on Form 5 based on the number of <nonDerivativeHolding> and <derivativeHolding> elements with a <transactionFormType> value of “3.” If at least one “3” holding is being reported, EDGAR will set this element to true (1). Otherwise, it will be set to false (0).\nVARCHAR (1)\nYes\n \nFORM4_TRANS_REPORTED\nEDGAR derived value on Form 5 based on the number of <nonDerivativeTransaction> and <derivativeTransaction> elements with a <transactionFormType> value of “4.” If at least one “4” transaction is being reported, EDGAR will set this element to true (1). Otherwise, it will be set to false (0).\nVARCHAR(1)\nYes\n \nDOCUMENT_TYPE\nSubmission type is either an initial filing Form 3, 4, 5 or an amendment of either 3/A, 4/A or 5/A.\nVARCHAR (20)\nNo\n \nISSUERCIK\nCentral Index Key of issuer.\nVARCHAR2 (10)\nNo\n \nISSUERNAME\nName of the issuer.\nVARCHAR2 (150)\nNo\n \nISSUERTRADINGSYMBOL\nIssuer trading symbol.\nVARCHAR2 (10)\nNo\n \nREMARKS\nRemarks from reporting owner.\nVARCHAR2 (2000)\nYes\n'

# %%
"""
NONDERIV_TRANS

Field Name | Description | Data Type | Nullable |Key

ACCESSION_NUMBER
Unique identifier assigned by the SEC to each EDGAR submission.
VARCHAR2 (25)
No
*
NONDERIV_TRANS_SK
Non-derivative transaction surrogate key.
NUMBER(38)
No
*
SECURITY_TITLE
Security title
VARCHAR2 (60)
No
 
SECURITY_TITLE_FN
Security title footnote id.
VARCHAR (150)
Yes
 
TRANS_DATE
Transaction date in (DD-MON-YYYY) format.
DATE
No
 
TRANS_DATE_FN
Transaction date footnote id.
VARCHAR (150)
Yes
 
DEEMED_EXECUTION_DATE
Deemed execution date in (DD-MON-YYYY) format.
DATE
Yes
 
DEEMED_EXECUTION_DATE_FN
Deemed execution date footnote id.
VARCHAR (150)
Yes
 
TRANS_FORM_TYPE
Transaction form type.
VARCHAR2 (1)
Yes
 
TRANS_CODE
Transaction code (values and descriptions are listed in the Appendix section 6.2 Trans Code List).
VARCHAR2 (1)
Yes
 
EQUITY_SWAP_INVOLVED
Indicator to show if the transaction involves an equity swap.
CHAR(1)
Yes
 
EQUITY_SWAP_TRANS_CD_FN
Transaction involving equity swap footnote id.
VARCHAR (150)
Yes
 
TRANS_TIMELINESS
Transaction timeliness (values and meanings are listed in the Appendix section 6.1 Trans Timeliness).
VARCHAR2 (1)
Yes
 
TRANS_TIMELINESS_FN
Transaction timeliness footnote id.
VARCHAR (150)
Yes
 
TRANS_SHARES
Transaction shares reported when Securities Acquired (A) or Disposed of (D).
NUMBER(16,2)
Yes
 
TRANS_SHARES_FN
Transaction shares reported when Securities Acquired (A) or Disposed of (D) footnote id.
VARCHAR (150)
Yes
 
TRANS_PRICEPERSHARE
Price of non-Derivative Transaction Security.
NUMBER(16,2)
Yes
 
TRANS_PRICEPERSHARE_FN
Price of non-Derivative Transaction Security footnote id.
VARCHAR (150)
Yes
 
TRANS_ACQUIRED_DISP_CD
Transaction code reported when Securities Acquired (A) or Disposed of (D).
VARCHAR2 (1)
No
 
TRANS_ACQUIRED_DISP_CD_FN
Transaction code reported when Securities Acquired (A) or Disposed of (D) footnote id.
VARCHAR (150)
Yes
 
SHRS_OWND_FOLWNG_TRANS
Shares owned following reported transaction(s).
NUMBER(16,2)
Yes
 
SHRS_OWND_FOLWNG_TRANS_FN
Shares owned following reported transaction(s) footnote id.
VARCHAR (150)
Yes
 
VALU_OWND_FOLWNG_TRANS
Value owned following reported transaction(s).
NUMBER(16,2)
Yes
 
VALU_OWND_FOLWNG_TRANS_FN
Value owned following reported transaction(s) footnote id.
VARCHAR (150)
Yes
 
DIRECT_INDIRECT_OWNERSHIP
Direct or Indirect ownership.
VARCHAR(5)
No
 
DIRECT_INDIRECT_OWNERSHIP_FN
Direct or Indirect ownership footnote id.
VARCHAR (150)
Yes
 
NATURE_OF_OWNERSHIP
Nature of ownership.
VARCHAR2 (100)
Yes
 
NATURE_OF_OWNERSHIP_FN
Nature of ownership footnote id.
VARCHAR (150)
Yes
"""
# Out:
# '\nNONDERIV_TRANS\n\nField Name | Description | Data Type | Nullable |Key\n\nACCESSION_NUMBER\nUnique identifier assigned by the SEC to each EDGAR submission.\nVARCHAR2 (25)\nNo\n*\nNONDERIV_TRANS_SK\nNon-derivative transaction surrogate key.\nNUMBER(38)\nNo\n*\nSECURITY_TITLE\nSecurity title\nVARCHAR2 (60)\nNo\n \nSECURITY_TITLE_FN\nSecurity title footnote id.\nVARCHAR (150)\nYes\n \nTRANS_DATE\nTransaction date in (DD-MON-YYYY) format.\nDATE\nNo\n \nTRANS_DATE_FN\nTransaction date footnote id.\nVARCHAR (150)\nYes\n \nDEEMED_EXECUTION_DATE\nDeemed execution date in (DD-MON-YYYY) format.\nDATE\nYes\n \nDEEMED_EXECUTION_DATE_FN\nDeemed execution date footnote id.\nVARCHAR (150)\nYes\n \nTRANS_FORM_TYPE\nTransaction form type.\nVARCHAR2 (1)\nYes\n \nTRANS_CODE\nTransaction code (values and descriptions are listed in the Appendix section 6.2 Trans Code List).\nVARCHAR2 (1)\nYes\n \nEQUITY_SWAP_INVOLVED\nIndicator to show if the transaction involves an equity swap.\nCHAR(1)\nYes\n \nEQUITY_SWAP_TRANS_CD_FN\nTransaction involving equity swap footnote id.\nVARCHAR (150)\nYes\n \nTRANS_TIMELINESS\nTransaction timeliness (values and meanings are listed in the Appendix section 6.1 Trans Timeliness).\nVARCHAR2 (1)\nYes\n \nTRANS_TIMELINESS_FN\nTransaction timeliness footnote id.\nVARCHAR (150)\nYes\n \nTRANS_SHARES\nTransaction shares reported when Securities Acquired (A) or Disposed of (D).\nNUMBER(16,2)\nYes\n \nTRANS_SHARES_FN\nTransaction shares reported when Securities Acquired (A) or Disposed of (D) footnote id.\nVARCHAR (150)\nYes\n \nTRANS_PRICEPERSHARE\nPrice of non-Derivative Transaction Security.\nNUMBER(16,2)\nYes\n \nTRANS_PRICEPERSHARE_FN\nPrice of non-Derivative Transaction Security footnote id.\nVARCHAR (150)\nYes\n \nTRANS_ACQUIRED_DISP_CD\nTransaction code reported when Securities Acquired (A) or Disposed of (D).\nVARCHAR2 (1)\nNo\n \nTRANS_ACQUIRED_DISP_CD_FN\nTransaction code reported when Securities Acquired (A) or Disposed of (D) footnote id.\nVARCHAR (150)\nYes\n \nSHRS_OWND_FOLWNG_TRANS\nShares owned following reported transaction(s).\nNUMBER(16,2)\nYes\n \nSHRS_OWND_FOLWNG_TRANS_FN\nShares owned following reported transaction(s) footnote id.\nVARCHAR (150)\nYes\n \nVALU_OWND_FOLWNG_TRANS\nValue owned following reported transaction(s).\nNUMBER(16,2)\nYes\n \nVALU_OWND_FOLWNG_TRANS_FN\nValue owned following reported transaction(s) footnote id.\nVARCHAR (150)\nYes\n \nDIRECT_INDIRECT_OWNERSHIP\nDirect or Indirect ownership.\nVARCHAR(5)\nNo\n \nDIRECT_INDIRECT_OWNERSHIP_FN\nDirect or Indirect ownership footnote id.\nVARCHAR (150)\nYes\n \nNATURE_OF_OWNERSHIP\nNature of ownership.\nVARCHAR2 (100)\nYes\n \nNATURE_OF_OWNERSHIP_FN\nNature of ownership footnote id.\nVARCHAR (150)\nYes\n'

# %%
#!pip install yfinance

import yfinance as yf

# %%
import pandas as pd

ticker = 'AAPL'

data = yf.Ticker(ticker)

df = data.history(period='1d', start='2010-1-1', end='2023-1-25')

df.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-01-04 00:00:00-05:00  6.478690  6.511170  6.446818  6.496296  493729600
# 2010-01-05 00:00:00-05:00  6.514204  6.544256  6.473224  6.507526  601904800
# 2010-01-06 00:00:00-05:00  6.507525  6.533327  6.397336  6.404014  552160000
# 2010-01-07 00:00:00-05:00  6.427692  6.435281  6.345733  6.392176  477131200
# 2010-01-08 00:00:00-05:00  6.383677  6.435281  6.346037  6.434673  447610800
#
#                            Dividends  Stock Splits
# Date
# 2010-01-04 00:00:00-05:00        0.0           0.0
# 2010-01-05 00:00:00-05:00        0.0           0.0
# 2010-01-06 00:00:00-05:00        0.0           0.0
# 2010-01-07 00:00:00-05:00        0.0           0.0
# 2010-01-08 00:00:00-05:00        0.0           0.0

# %%
trans_df = pd.read_csv('Insider-Transactions-Data-Sets/2023q1_form345/NONDERIV_TRANS.tsv', sep='\t')
sub_df = pd.read_csv('Insider-Transactions-Data-Sets/2023q1_form345/SUBMISSION.tsv', sep='\t')

merged_df = pd.merge(trans_df, sub_df, on='ACCESSION_NUMBER')

merged_df.head()
# Out:
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/810061891.py:1: DtypeWarning: Columns (13,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   trans_df = pd.read_csv('Insider-Transactions-Data-Sets/2023q1_form345/NONDERIV_TRANS.tsv', sep='\t')
#        ACCESSION_NUMBER  NONDERIV_TRANS_SK  \
# 0  0001787306-23-000025            6348733
# 1  0001104659-23-040415            6348570
# 2  0001104659-23-040415            6348571
# 3  0001140361-23-015527            6348879
# 4  0001140361-23-015527            6348878
#
#                                SECURITY_TITLE SECURITY_TITLE_FN   TRANS_DATE  \
# 0                                Common Stock               NaN  02-MAR-2023
# 1                                Common Stock               NaN  29-MAR-2023
# 2                                Common Stock               NaN  29-MAR-2023
# 3  Ordinary Shares, par value $0.01 per share               NaN  29-MAR-2023
# 4  Ordinary Shares, par value $0.01 per share               NaN  29-MAR-2023
#
#   TRANS_DATE_FN DEEMED_EXECUTION_DATE DEEMED_EXECUTION_DATE_FN  \
# 0           NaN                   NaN                      NaN
# 1           NaN                   NaN                      NaN
# 2           NaN                   NaN                      NaN
# 3           NaN                   NaN                      NaN
# 4           NaN                   NaN                      NaN
#
#    TRANS_FORM_TYPE TRANS_CODE  ... DATE_OF_ORIG_SUB NO_SECURITIES_OWNED  \
# 0                4          A  ...      28-FEB-2023                 NaN
# 1                4          M  ...              NaN                 NaN
# 2                4          S  ...              NaN                 NaN
# 3                4          S  ...              NaN                 NaN
# 4                4          S  ...              NaN                 NaN
#
#   NOT_SUBJECT_SEC16 FORM3_HOLDINGS_REPORTED  FORM4_TRANS_REPORTED  \
# 0                 0                     NaN                   NaN
# 1                 0                     NaN                   NaN
# 2                 0                     NaN                   NaN
# 3               NaN                     NaN                   NaN
# 4               NaN                     NaN                   NaN
#
#   DOCUMENT_TYPE  ISSUERCIK                     ISSUERNAME ISSUERTRADINGSYMBOL  \
# 0           4/A    1787306  Arcutis Biotherapeutics, Inc.                ARQT
# 1             4    1649904   RHYTHM PHARMACEUTICALS, INC.                RYTM
# 2             4    1649904   RHYTHM PHARMACEUTICALS, INC.                RYTM
# 3             4    1559053    PROTHENA CORP PUBLIC LTD CO                PRTA
# 4             4    1559053    PROTHENA CORP PUBLIC LTD CO                PRTA
#
#                                              REMARKS
# 0  Reporting Person's title: Chief Executive Offi...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 40 columns]

# %%
import os
import pandas as pd

path = 'Insider-Transactions-Data-Sets/'

all_dirs = os.listdir(path)

all_dirs
# Out:
# ['2017q3_form345',
#  '2018q4_form345',
#  '2022q3_form345',
#  '2010q1_form345',
#  '2008q2_form345',
#  '2015q4_form345',
#  '2011q2_form345',
#  '2020q4_form345',
#  '2009q1_form345',
#  '2016q1_form345',
#  '.DS_Store',
#  '2011q3_form345',
#  '2023q1_form345',
#  '2017q2_form345',
#  '2007q4_form345',
#  '2022q2_form345',
#  '2013q4_form345',
#  '2008q3_form345',
#  '2019q4_form345',
#  '2016q3_form345',
#  '2009q2_form345',
#  '2011q1_form345',
#  '2014q4_form345',
#  '2021q4_form345',
#  '2008q1_form345',
#  '2010q2_form345',
#  '2017q1_form345',
#  '2010q3_form345',
#  '2022q1_form345',
#  '2016q2_form345',
#  '2012q4_form345',
#  '2009q3_form345',
#  '2006q4_form345',
#  '2020q3_form345',
#  '2012q1_form345',
#  '2006q1_form345',
#  '2015q3_form345',
#  '2013q2_form345',
#  '2007q2_form345',
#  '2022q4_form345',
#  '2018q3_form345',
#  '2017q4_form345',
#  '2013q3_form345',
#  '2021q1_form345',
#  '2008q4_form345',
#  '2007q3_form345',
#  '2018q2_form345',
#  '2014q1_form345',
#  '2020q2_form345',
#  '2011q4_form345',
#  '2015q2_form345',
#  '2019q1_form345',
#  '2007q1_form345',
#  '2021q3_form345',
#  '2013q1_form345',
#  '2014q3_form345',
#  '2006q2_form345',
#  '2012q2_form345',
#  '2016q4_form345',
#  '2019q3_form345',
#  '2006q3_form345',
#  '2012q3_form345',
#  '2020q1_form345',
#  '2009q4_form345',
#  '2019q2_form345',
#  '2015q1_form345',
#  '2010q4_form345',
#  '2021q2_form345',
#  '2014q2_form345',
#  '2018q1_form345']

# %%
import os
import pandas as pd

def read_tsv(path, file_name):
    all_dirs = [name for name in os.listdir(path) if name.startswith('2')]

    dirs = [name for name in all_dirs if int(name[:4]) >= 2021]
    
    dfs = []

    for directory in dirs:
        tsv_path = os.path.join(path, directory, file_name)
        df = pd.read_csv(tsv_path, sep='\t')
        dfs.append(df)

    df = pd.concat(dfs, ignore_index=True)

    return df


path = 'Insider-Transactions-Data-Sets/'

trans_df = read_tsv(path, 'NONDERIV_TRANS.tsv')

sub_df = read_tsv(path, 'SUBMISSION.tsv')

trans_df = pd.merge(trans_df, sub_df, on='ACCESSION_NUMBER')

trans_df.head()
# Out:
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2914740898.py:13: DtypeWarning: Columns (13,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2914740898.py:13: DtypeWarning: Columns (13,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2914740898.py:13: DtypeWarning: Columns (7,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2914740898.py:13: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2914740898.py:13: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2914740898.py:13: DtypeWarning: Columns (7,13,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2914740898.py:13: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2914740898.py:13: DtypeWarning: Columns (7,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(tsv_path, sep='\t')
#        ACCESSION_NUMBER  NONDERIV_TRANS_SK                  SECURITY_TITLE  \
# 0  0001868645-22-000001            6184592            Class A common stock
# 1  0001868212-22-000002            6185104            Class A common stock
# 2  0001104659-22-104798            6184705        Series X Preferred Stock
# 3  0001104659-22-104797            6184933  Common Stock, par value $0.001
# 4  0001104659-22-104796            6184656  Common Stock, par value $0.001
#
#   SECURITY_TITLE_FN   TRANS_DATE TRANS_DATE_FN DEEMED_EXECUTION_DATE  \
# 0               NaN  28-SEP-2022           NaN                   NaN
# 1               NaN  28-SEP-2022           NaN                   NaN
# 2               NaN  28-SEP-2022           NaN                   NaN
# 3               NaN  28-SEP-2022           NaN                   NaN
# 4               NaN  28-SEP-2022           NaN                   NaN
#
#   DEEMED_EXECUTION_DATE_FN  TRANS_FORM_TYPE TRANS_CODE  ... DATE_OF_ORIG_SUB  \
# 0                      NaN                4          C  ...              NaN
# 1                      NaN                4          C  ...              NaN
# 2                      NaN                4          J  ...              NaN
# 3                      NaN                4          A  ...              NaN
# 4                      NaN                4          A  ...              NaN
#
#   NO_SECURITIES_OWNED NOT_SUBJECT_SEC16 FORM3_HOLDINGS_REPORTED  \
# 0                 NaN                 0                     NaN
# 1                 NaN                 0                     NaN
# 2                 NaN                 0                     NaN
# 3                 NaN                 0                     NaN
# 4                 NaN                 0                     NaN
#
#    FORM4_TRANS_REPORTED DOCUMENT_TYPE  ISSUERCIK                   ISSUERNAME  \
# 0                   NaN             4    1854963           SHF Holdings, Inc.
# 1                   NaN             4    1854963           SHF Holdings, Inc.
# 2                   NaN             4     861838  IDERA PHARMACEUTICALS, INC.
# 3                   NaN             4     861838  IDERA PHARMACEUTICALS, INC.
# 4                   NaN             4     861838  IDERA PHARMACEUTICALS, INC.
#
#   ISSUERTRADINGSYMBOL REMARKS
# 0                SHFS     NaN
# 1                SHFS     NaN
# 2                IDRA     NaN
# 3                IDRA     NaN
# 4                IDRA     NaN
#
# [5 rows x 40 columns]

# %%
features = ['ACCESSION_NUMBER', 'NONDERIV_TRANS_SK', 'SECURITY_TITLE', 'TRANS_DATE', 'TRANS_CODE', 'TRANS_SHARES', 'SHRS_OWND_FOLWNG_TRANS', 'ISSUERCIK', 'ISSUERNAME', 'ISSUERTRADINGSYMBOL']
trans_df = trans_df[features]

trans_df
# Out:
#             ACCESSION_NUMBER  NONDERIV_TRANS_SK  \
# 0       0001868645-22-000001            6184592
# 1       0001868212-22-000002            6185104
# 2       0001104659-22-104798            6184705
# 3       0001104659-22-104797            6184933
# 4       0001104659-22-104796            6184656
# ...                      ...                ...
# 767187  0000899243-21-014312             215214
# 767188  0000899243-21-014312             215216
# 767189  0001140361-21-011133              57006
# 767190  0001140361-21-011133              57005
# 767191  0001140361-21-011133              57007
#
#                         SECURITY_TITLE   TRANS_DATE TRANS_CODE  TRANS_SHARES  \
# 0                 Class A common stock  28-SEP-2022          C     2835000.0
# 1                 Class A common stock  28-SEP-2022          C     2835000.0
# 2             Series X Preferred Stock  28-SEP-2022          J           5.0
# 3       Common Stock, par value $0.001  28-SEP-2022          A     2171214.0
# 4       Common Stock, par value $0.001  28-SEP-2022          A     2171214.0
# ...                                ...          ...        ...           ...
# 767187                    Common Stock  30-MAR-2021          S       11461.0
# 767188                    Common Stock  30-MAR-2021          S        3130.0
# 767189            Class A Common Stock  26-MAR-2021          S      132633.0
# 767190            Class A Common Stock  26-MAR-2021          S      809914.0
# 767191            Class A Common Stock  26-MAR-2021          S      656254.0
#
#         SHRS_OWND_FOLWNG_TRANS  ISSUERCIK                   ISSUERNAME  \
# 0                    3363175.0    1854963           SHF Holdings, Inc.
# 1                    3363175.0    1854963           SHF Holdings, Inc.
# 2                          5.0     861838  IDERA PHARMACEUTICALS, INC.
# 3                    2171214.0     861838  IDERA PHARMACEUTICALS, INC.
# 4                    2171214.0     861838  IDERA PHARMACEUTICALS, INC.
# ...                        ...        ...                          ...
# 767187                241600.0    1787400                 Nkarta, Inc.
# 767188                236061.0    1787400                 Nkarta, Inc.
# 767189               1760693.0    1801368      MP Materials Corp. / DE
# 767190              10751559.0    1801368      MP Materials Corp. / DE
# 767191               8711753.0    1801368      MP Materials Corp. / DE
#
#        ISSUERTRADINGSYMBOL
# 0                     SHFS
# 1                     SHFS
# 2                     IDRA
# 3                     IDRA
# 4                     IDRA
# ...                    ...
# 767187                NKTX
# 767188                NKTX
# 767189                  MP
# 767190                  MP
# 767191                  MP
#
# [767192 rows x 10 columns]

# %%
print(trans_df['TRANS_DATE'].dtypes)
trans_df['TRANS_DATE'] = pd.to_datetime(trans_df['TRANS_DATE'])
print(trans_df['TRANS_DATE'].dtypes)

trans_df.head()

print(trans_df['TRANS_DATE'])
print(trans_df['TRANS_DATE'].dtypes)
print(trans_df['TRANS_DATE'].min())
# Out:
# object
# datetime64[ns]
# 0        2022-09-28
# 1        2022-09-28
# 2        2022-09-28
# 3        2022-09-28
# 4        2022-09-28
#             ...
# 767187   2021-03-30
# 767188   2021-03-30
# 767189   2021-03-26
# 767190   2021-03-26
# 767191   2021-03-26
# Name: TRANS_DATE, Length: 767192, dtype: datetime64[ns]
# datetime64[ns]
# 1999-01-01 00:00:00

# %%
duplicates = trans_df[trans_df.duplicated(keep=False)]

duplicates
# Out:
# Empty DataFrame
# Columns: [ACCESSION_NUMBER, NONDERIV_TRANS_SK, SECURITY_TITLE, TRANS_DATE, TRANS_CODE, TRANS_SHARES, SHRS_OWND_FOLWNG_TRANS, ISSUERCIK, ISSUERNAME, ISSUERTRADINGSYMBOL]
# Index: []

# %%
trans_df.isnull().sum()
# Out:
# ACCESSION_NUMBER             0
# NONDERIV_TRANS_SK            0
# SECURITY_TITLE               0
# TRANS_DATE                   0
# TRANS_CODE                   0
# TRANS_SHARES                 0
# SHRS_OWND_FOLWNG_TRANS     222
# ISSUERCIK                    0
# ISSUERNAME                1351
# ISSUERTRADINGSYMBOL        976
# dtype: int64

# %%
missing_shares = trans_df[trans_df['SHRS_OWND_FOLWNG_TRANS'].isnull()]
missing_shares
# Out:
#             ACCESSION_NUMBER  NONDERIV_TRANS_SK  \
#
RANS_SHARES  SHRS_OWND_FOLWNG_TRANS  ISSUERCIK  \
# 1462         1000.00                 2000.00    1895316
# 4057            5.00                 1860.00    1352081
# 4058            4.00                 1855.00    1352081
# 4233       550960.00              4062567.00    1711929
# 4997       540000.00               772000.00    1901297
# ...              ...                     ...        ...
# 767037     971359.75              8528572.73    1742952
# 767099          6.00                  642.00    1352081
# 767100          4.00                  636.00    1352081
# 767101          4.00                  632.00    1352081
# 767122         30.00                 1820.00    1352081
#
#                                      ISSUERNAME ISSUERTRADINGSYMBOL
# 1462                  Brightwood Capital Corp I                 NaN
# 4057                       Cardinal Ethanol LLC                 NaN
# 4058                       Cardinal Ethanol LLC                 NaN
# 4233    Starwood Real Estate Income Trust, Inc.                 NaN
# 4997           Harmony Energy Technologies Corp                 NaN
# ...                                         ...                 ...
# 767037           John Hancock GA Mortgage Trust                 NaN
# 767099                     Cardinal Ethanol LLC                 NaN
# 767100                     Cardinal Ethanol LLC                 NaN
# 767101                     Cardinal Ethanol LLC                 NaN
# 767122                     Cardinal Ethanol LLC                 NaN
#
# [976 rows x 10 columns]

# %%
missing_issuer = trans_df[trans_df['ISSUERNAME'].isnull() & trans_df['ISSUERTRADINGSYMBOL'].isnull()]
missing_issuer
# Out:
#            ACCESSION_NUMBER  NONDERIV_TRANS_SK         SECURITY_TITLE  \
# 25090  0000899243-22-029122            6159035  Class I Common Shares
#
#       TRANS_DATE TRANS_CODE  TRANS_SHARES  SHRS_OWND_FOLWNG_TRANS  ISSUERCIK  \
# 25090 2022-08-17          J      405401.0                139826.0    1711929
#
#       ISSUERNAME ISSUERTRADINGSYMBOL
# 25090        NaN                 NaN

# %%
trans_df = trans_df.dropna(subset=['ISSUERNAME', 'ISSUERTRADINGSYMBOL'], how='all')

trans_df
# Out:
#             ACCESSION_NUMBER  NONDERIV_TRANS_SK  \
# 0       0001868645-22-000001            6184592
# 1       0001868212-22-000002            6185104
# 2       0001104659-22-104798            6184705
# 3       0001104659-22-104797            6184933
# 4       0001104659-22-104796            6184656
# ...                      ...                ...
# 767187  0000899243-21-014312             215214
# 767188  0000899243-21-014312             215216
# 767189  0001140361-21-011133              57006
# 767190  0001140361-21-011133              57005
# 767191  0001140361-21-011133              57007
#
#                         SECURITY_TITLE TRANS_DATE TRANS_CODE  TRANS_SHARES  \
# 0                 Class A common stock 2022-09-28          C     2835000.0
# 1                 Class A common stock 2022-09-28          C     2835000.0
# 2             Series X Preferred Stock 2022-09-28          J           5.0
# 3       Common Stock, par value $0.001 2022-09-28          A     2171214.0
# 4       Common Stock, par value $0.001 2022-09-28          A     2171214.0
# ...                                ...        ...        ...           ...
# 767187                    Common Stock 2021-03-30          S       11461.0
# 767188                    Common Stock 2021-03-30          S        3130.0
# 767189            Class A Common Stock 2021-03-26          S      132633.0
# 767190            Class A Common Stock 2021-03-26          S      809914.0
# 767191            Class A Common Stock 2021-03-26          S      656254.0
#
#         SHRS_OWND_FOLWNG_TRANS  ISSUERCIK                   ISSUERNAME  \
# 0                    3363175.0    1854963           SHF Holdings, Inc.
# 1                    3363175.0    1854963           SHF Holdings, Inc.
# 2                          5.0     861838  IDERA PHARMACEUTICALS, INC.
# 3                    2171214.0     861838  IDERA PHARMACEUTICALS, INC.
# 4                    2171214.0     861838  IDERA PHARMACEUTICALS, INC.
# ...                        ...        ...                          ...
# 767187                241600.0    1787400                 Nkarta, Inc.
# 767188                236061.0    1787400                 Nkarta, Inc.
# 767189               1760693.0    1801368      MP Materials Corp. / DE
# 767190              10751559.0    1801368      MP Materials Corp. / DE
# 767191               8711753.0    1801368      MP Materials Corp. / DE
#
#        ISSUERTRADINGSYMBOL
# 0                     SHFS
# 1                     SHFS
# 2                     IDRA
# 3                     IDRA
# 4                     IDRA
# ...                    ...
# 767187                NKTX
# 767188                NKTX
# 767189                  MP
# 767190                  MP
# 767191                  MP
#
# [767191 rows x 10 columns]

# %%
trans_df.columns
# Out:
# Index(['ACCESSION_NUMBER', 'NONDERIV_TRANS_SK', 'SECURITY_TITLE', 'TRANS_DATE',
#        'TRANS_CODE', 'TRANS_SHARES', 'SHRS_OWND_FOLWNG_TRANS', 'ISSUERCIK',
#        'ISSUERNAME', 'ISSUERTRADINGSYMBOL'],
#       dtype='object')

# %%
"""
- The number of transactions over time (per week or per month)
- The distribution of transaction types over time
- The number of transactions per issuer
- The correlation between the number of shares transacted and the stock price
"""
# Out:
# '\n- The number of transactions over time (per week or per month)\n- The distribution of transaction types over time\n- The number of transactions per issuer\n- The correlation between the number of shares transacted and the stock price\n'

# %%
import matplotlib.pyplot as plt

start_date = pd.to_datetime('2021-01-01')
end_date = pd.to_datetime('2023-04-01')

filtered_df = trans_df[(trans_df['TRANS_DATE'] >= start_date) & (trans_df['TRANS_DATE'] < end_date)]

filtered_df['YEAR_QUARTER'] = filtered_df['TRANS_DATE'].dt.to_period('Q')
filtered_df['YEAR_QUARTER'].value_counts().sort_index().plot(kind='bar', figsize=(10,5))
plt.title('Number of transactions per quarter (2021 - 2023 Q1)')
plt.xlabel('Quarter')
plt.ylabel('Number of transactions')
plt.show()
# Out:
# /var/folders/6n/xx_w7xj16q5gfbt_pm8vdmvh0000gn/T/ipykernel_66572/2734227343.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['YEAR_QUARTER'] = filtered_df['TRANS_DATE'].dt.to_period('Q')

# %%
import pandas as pd

date_str = "01-JUL-2022"

date = pd.to_datetime(date_str, format="%d-%b-%Y")

print(date)
trans_df['TRANS_DATE'].dtypes
# Out:
# 2022-07-01 00:00:00
# dtype('<M8[ns]')

# %%
print("Earliest transaction date:", trans_df['TRANS_DATE'].min())
print("Latest transaction date:", trans_df['TRANS_DATE'].max())
# Out:
# Earliest transaction date: 1999-01-01 00:00:00
# Latest transaction date: 2033-11-18 00:00:00

# %%
trans_df['TRANS_CODE'].value_counts().plot(kind='bar', figsize=(10,5))
plt.title('Distribution of transaction types')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.show()

# %%
top_issuers = trans_df['ISSUERNAME'].value_counts().nlargest(10)
top_issuers.plot(kind='bar', figsize=(10,5))
plt.title('Number of transactions per issuer')
plt.xlabel('Issuer')
plt.ylabel('Number of transactions')
plt.show()

# %%
trans_df['TRANS_SHARES'].plot(kind='hist', bins=30, figsize=(10,5), logy=True)
plt.title('Distribution of the number of shares transacted')
plt.xlabel('Number of shares')
plt.ylabel('Frequency')
plt.show()

# %%
trans_df.columns
# Out:
# Index(['ACCESSION_NUMBER', 'NONDERIV_TRANS_SK', 'SECURITY_TITLE', 'TRANS_DATE',
#        'TRANS_CODE', 'TRANS_SHARES', 'SHRS_OWND_FOLWNG_TRANS', 'ISSUERCIK',
#        'ISSUERNAME', 'ISSUERTRADINGSYMBOL'],
#       dtype='object')

# %%
trans_df = trans_df[['ACCESSION_NUMBER', 'NONDERIV_TRANS_SK', 'TRANS_DATE', 'TRANS_CODE', 'TRANS_SHARES', 'SHRS_OWND_FOLWNG_TRANS', 'ISSUERCIK', 'ISSUERNAME', 'ISSUERTRADINGSYMBOL']]
trans_df['TRANS_CODE'].value_counts()

trans_types = ['S', 'A', 'F', 'M', 'P', 'J', 'G', 'C', 'D']
trans_df = trans_df[trans_df['TRANS_CODE'].isin(trans_types)]

trans_df
# Out:
#             ACCESSION_NUMBER  NONDERIV_TRANS_SK TRANS_DATE TRANS_CODE  \
# 0       0001868645-22-000001            6184592 2022-09-28          C
# 1       0001868212-22-000002            6185104 2022-09-28          C
# 2       0001104659-22-104798            6184705 2022-09-28          J
# 3       0001104659-22-104797            6184933 2022-09-28          A
# 4       0001104659-22-104796            6184656 2022-09-28          A
# ...                      ...                ...        ...        ...
# 767187  0000899243-21-014312             215214 2021-03-30          S
# 767188  0000899243-21-014312             215216 2021-03-30          S
# 767189  0001140361-21-011133              57006 2021-03-26          S
# 767190  0001140361-21-011133              57005 2021-03-26          S
# 767191  0001140361-21-011133              57007 2021-03-26          S
#
#         TRANS_SHARES  SHRS_OWND_FOLWNG_TRANS  ISSUERCIK  \
# 0          2835000.0               3363175.0    1854963
# 1          2835000.0               3363175.0    1854963
# 2                5.0                     5.0     861838
# 3          2171214.0               2171214.0     861838
# 4          2171214.0               2171214.0     861838
# ...              ...                     ...        ...
# 767187       11461.0                241600.0    1787400
# 767188        3130.0                236061.0    1787400
# 767189      132633.0               1760693.0    1801368
# 767190      809914.0              10751559.0    1801368
# 767191      656254.0               8711753.0    1801368
#
#                          ISSUERNAME ISSUERTRADINGSYMBOL
# 0                SHF Holdings, Inc.                SHFS
# 1                SHF Holdings, Inc.                SHFS
# 2       IDERA PHARMACEUTICALS, INC.                IDRA
# 3       IDERA PHARMACEUTICALS, INC.                IDRA
# 4       IDERA PHARMACEUTICALS, INC.                IDRA
# ...                             ...                 ...
# 767187                 Nkarta, Inc.                NKTX
# 767188                 Nkarta, Inc.                NKTX
# 767189      MP Materials Corp. / DE                  MP
# 767190      MP Materials Corp. / DE                  MP
# 767191      MP Materials Corp. / DE                  MP
#
# [763101 rows x 9 columns]

# %%
trans_df.isnull().sum()
# Out:
# ACCESSION_NUMBER             0
# NONDERIV_TRANS_SK            0
# TRANS_DATE                   0
# TRANS_CODE                   0
# TRANS_SHARES                 0
# SHRS_OWND_FOLWNG_TRANS     221
# ISSUERCIK                    0
# ISSUERNAME                1343
# ISSUERTRADINGSYMBOL        972
# dtype: int64

# %%
trans_df_encoded = pd.get_dummies(trans_df, columns=['TRANS_CODE'])

# %%
trans_df_encoded
# Out:
#             ACCESSION_NUMBER  NONDERIV_TRANS_S
             0             0             0             0
# ...              ...           ...           ...           ...           ...
# 88361              0             0             0             0             0
# 74557              0             0             0             0             0
# 65591              0             0             0             0             0
# 59263              0             0             0             0             0
# 55155              0             0             0             0             0
#
#         TRANS_CODE_S
# 554305             0
# 554318             0
# 554273             0
# 554274             0
# 602906             1
# ...              ...
# 88361              1
# 74557              1
# 65591              1
# 59263              1
# 55155              1
#
# [5399 rows x 17 columns]

# %%
dates = pd.date_range('2021-01-01', '2023-03-30')

date_df = pd.DataFrame(index=dates)

fb_transactions.set_index('TRANS_DATE', inplace=True)
fb_transactions = fb_transactions.groupby(fb_transactions.index).sum()

fb_transactions = fb_transactions.fillna(0)

fb_transactions
# Out:
#             NONDERIV_TRANS_SK  TRANS_SHARES  SHRS_OWND_FOLWNG_TRANS  \
# TRANS_DATE
# 2020-11-06             138937      145000.0                 43048.0
# 2020-11-19             430277      143925.0               2126782.0
# 2020-12-30            1588870       78591.0              21132657.0
# 2020-12-31            4844301       80607.0              21064067.0
# 2021-01-04            6861135       78500.0              31499796.0
# ...                       ...           ...                     ...
# 2023-02-28            6313286         393.0                 31725.0
# 2023-03-07            6328744         393.0                 31332.0
# 2023-03-14            6337661         393.0                 30939.0
# 2023-03-21            6343155         393.0                 30546.0
# 2023-03-28            6348117         393.0                 30153.0
#
#             ISSUERCIK  TRANS_CODE_A  TRANS_CODE_C  TRANS_CODE_D  TRANS_CODE_F  \
# TRANS_DATE
# 2020-11-06    1326801             0             0             0             0
# 2020-11-19    3980403             0             0             0             0
# 2020-12-30   26536020             0             2             0             0
# 2020-12-31   27862821             0             2             0             0
# 2021-01-04   39804030             0             2             0             0
# ...               ...           ...           ...           ...           ...
# 2023-02-28    1326801             0             0             0             0
# 2023-03-07    1326801             0             0             0             0
# 2023-03-14    1326801             0             0             0             0
# 2023-03-21    1326801             0             0             0             0
# 2023-03-28    1326801             0             0             0             0
#
#             TRANS_CODE_G  TRANS_CODE_J  TRANS_CODE_M  TRANS_CODE_P  \
# TRANS_DATE
# 2020-11-06             1             0             0             0
# 2020-11-19             3             0             0             0
# 2020-12-30             0             0             0             0
# 2020-12-31             0             0             0             0
# 2021-01-04             0             0             0             0
# ...                  ...           ...           ...           ...
# 2023-02-28             0             0             0             0
# 2023-03-07             0             0             0             0
# 2023-03-14             0             0             0             0
# 2023-03-21             0             0             0             0
# 2023-03-28             0             0             0             0
#
#             TRANS_CODE_S
# TRANS_DATE
# 2020-11-06             0
# 2020-11-19             0
# 2020-12-30            18
# 2020-12-31            19
# 2021-01-04            28
# ...                  ...
# 2023-02-28             1
# 2023-03-07             1
# 2023-03-14             1
# 2023-03-21             1
# 2023-03-28             1
#
# [315 rows x 13 columns]

# %%
fb_trans_date = pd.merge(date_df, fb_transactions, how='left', left_index=True, right_index=True)

fb_trans_date = fb_trans_date.fillna(0)

fb_trans_date
# Out:
#             NONDERIV_TRANS_SK  TRANS_SHARES  SHRS_OWND_FOLWNG_TRANS
# 2021-01-03           0.0           0.0  274.779999  275.000000  265.200012
# 2021-01-04           0.0          28.0  274.779999  275.000000  265.200012
# 2021-01-05           0.0          13.0  268.290009  272.399994  268.209991
# ...                  ...           ...         ...         ...         ...
# 2023-03-26           0.0           0.0  205.179993  207.580002  203.550003
# 2023-03-27           0.0           0.0  204.809998  205.860001  201.360001
# 2023-03-28           0.0           1.0  200.149994  201.029999  197.899994
# 2023-03-29           0.0           0.0  203.559998  205.720001  202.539993
# 2023-03-30           0.0           0.0  203.380005  208.089996  202.820007
#
#                  Close   Adj Close      Volume
# 2021-01-01  268.940002  268.940002  15106100.0
# 2021-01-02  268.940002  268.940002  15106100.0
# 2021-01-03  268.940002  268.940002  15106100.0
# 2021-01-04  268.940002  268.940002  15106100.0
# 2021-01-05  270.970001  270.970001   9871600.0
# ...                ...         ...         ...
# 2023-03-26  206.009995  206.009995  27716400.0
# 2023-03-27  202.839996  202.839996  18527200.0
# 2023-03-28  200.679993  200.679993  19127300.0
# 2023-03-29  205.350006  205.350006  18851100.0
# 2023-03-30  207.839996  207.839996  22608300.0
#
# [819 rows x 19 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,7))
plt.plot(fb_data['Close'])
plt.title('Closing price of Meta Platforms, Inc.')
plt.xlabel('Date')
plt.ylabel('Closing price ($)')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

features = fb_data[['NONDERIV_TRANS_SK', 'TRANS_SHARES', 'SHRS_OWND_FOLWNG_TRANS', 'ISSUERCIK', 
                    'TRANS_CODE_A', 'TRANS_CODE_C', 'TRANS_CODE_D', 'TRANS_CODE_F', 
                    'TRANS_CODE_G', 'TRANS_CODE_J', 'TRANS_CODE_M', 'TRANS_CODE_P', 'TRANS_CODE_S',
                    'Open', 'High', 'Low', 'Volume']]

target = fb_data['Close']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print('The mean squared error:', mse)
# Out:
# The mean squared error: 4.513005563779294

# %%
y_pred
# Out:
# array([282.71877978, 196.82075989, 182.13676822, 204.34045094,
#        108.86630148, 163.47140717, 162.98761651, 190.74732258,
#        352.40998183, 157.65240856, 265.09162244, 337.54552832,
#         96.37732448, 358.73329814, 179.90025193, 198.06699575,
#        339.63863184, 163.03799491, 166.62431102, 140.03857341,
#        260.07906858, 192.62355056, 323.92383497, 317.78910296,
#        358.33647169, 168.63261184, 168.01915874, 257.42864294,
#        311.59669402, 271.10271582, 329.78893754, 127.68635842,
#        213.59720565, 256.19900719, 127.68682531, 156.14955296,
#        343.63987298, 277.0252727 , 149.85075011, 298.2911697 ,
#        120.04982471, 182.13676822, 358.33647169, 110.05767838,
#        161.30194322, 289.90410621, 327.58969598, 376.068803  ,
#        158.81032704, 358.48084412, 197.7094025 , 157.40545983,
#        131.99540702, 170.49400719, 157.40545983, 113.00233849,
#        208.99680529, 138.30232694, 117.5301682 , 197.10482811,
#        363.99352431, 169.64038781, 259.70409216, 317.09667615,
#        311.47048234, 375.40975116, 324.02977305, 157.86636813,
#        261.30538986, 171.01066447, 116.10543274, 128.01014319,
#         95.43447687, 337.04798948, 205.73615025, 266.58706446,
#        258.64143765, 228.92119713, 325.5689508 , 310.34084093,
#        300.15514552, 353.41053337, 201.36178043, 202.89770933,
#        265.40425514, 289.2681065 , 188.32291374, 191.55574379,
#        338.56207806, 333.77415688, 333.90915742, 329.32087582,
#        175.29108397, 210.87748133, 170.12500131, 197.36002562,
#        299.1056188 , 225.24234891, 347.2413715 , 154.10370953,
#        125.14129737, 264.12222307, 261.12744593, 182.13676822,
#        344.36948046, 205.84372693, 334.2267857 , 311.44066932,
#        167.27208775, 282.23008084, 114.81201735, 362.37327574,
#        171.2819113 , 185.88573904, 115.16321812, 188.32291374,
#        173.5481453 , 282.47280222, 258.11527031, 167.51720018,
#        298.20752597, 340.35608513, 198.32107477, 333.18040688,
#        330.44407672, 336.38881967, 186.15425927, 323.83530072,
#        160.75782587, 364.45910782, 257.42864294, 161.44104899,
#        128.01014319, 358.18322437, 111.6188602 , 293.83934073,
#        202.73624402, 340.42109868, 189.04389388, 119.78231716,
#        301.7082485 , 128.42964953, 208.283868  , 344.74602928,
#        138.5218465 ,  98.05691433, 119.78231716, 264.1413818 ,
#        115.98173496, 309.25753972, 313.46419103, 370.95513919,
#        338.72826793, 363.09803033, 267.01985061, 331.22669891,
#        205.03910427, 333.36895403, 128.01014319, 361.23741466,
#        215.12194902, 192.63687262, 200.1987828 , 115.60281815])

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create DataFrame for better handling
df_pred = pd.DataFrame(y_pred, index=y_test.index, columns=['Predicted'])

# Sort both y_test and df_pred
y_test_sorted = y_test.sort_index()
df_pred_sorted = df_pred.sort_index()

plt.figure(figsize=(12, 6))

# Plot the actual values
plt.plot(y_test_sorted.index, y_test_sorted.values, label='Actual', color='b')

# Plot the predicted values
plt.plot(df_pred_sorted.index, df_pred_sorted.values, label='Predicted', color='r')

# Set the title and labels
plt.title('Actual vs Predicted Closing Prices')
plt.xlabel('Date')
plt.ylabel('Price')

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
residuals = y_test - y_pred

print('Residuals mean:', residuals.mean())
print('Residuals standard deviation:', residuals.std())
# Out:
# Residuals mean: 0.14490358201599787
# Residuals standard deviation: 2.125927291830641

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print('MAE:', mae)
print('MSE:', mse)
print('RMSE:', rmse)
# Out:
# MAE: 1.6330857374038632
# MSE: 4.513005563779294
# RMSE: 2.12438357265803

# %%
"""
Trans Code List
 
Value | Meaning
A
Grant, award or other acquisition pursuant to Rule 16b-3(d)
C
Conversion of derivative security
D
Disposition to the issuer of issuer equity securities pursuant to Rule 16b-3(e)
E
Expiration of short derivative position
F
Payment of exercise price or tax liability by delivering or withholding securities incident to the receipt, exercise or vesting of a security issued in accordance with Rule 16b-3
G
Bona fide gift
H
Expiration (or cancellation) of long derivative position with value received
I
Discretionary transaction in accordance with Rule 16b-3(f) resulting in acquisition or disposition of issuer securities
J
Other acquisition or disposition (describe transaction)
L
Small acquisition under Rule 16a-6
M
Exercise or conversion of derivative security exempted pursuant to Rule 16b-3
O
Exercise of out-of-the-money derivative security
P
Open market or private purchase of non-derivative or derivative security
S
Open market or private sale of non-derivative or derivative security
U
Disposition pursuant to a tender of shares in a change of control transaction
W
Acquisition or disposition by will or the laws of descent and distribution
X
Exercise of in-the-money or at-the-money derivative security
Z
Deposit into or withdrawal from voting trust
"""

# %%
fb_data.drop(['NONDERIV_TRANS_SK', 'ISSUERCIK'], axis=1, inplace=True)
